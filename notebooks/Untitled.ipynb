# %%
from sympy import symbols, solve, Eq, latex, init_printing, preview
from os.path import join
import numpy as np
from model import *
from sympy.plotting import plot,plot_implicit
init_printing()

# %%
J_At,J_Oa
# Out:
# ⎛       R⋅\mu_{At}         R⋅\mu_{Oa}⎞
# ⎜J_At = ──────────, J_Oa = ──────────⎟
# ⎝       K_{At} + R         K_{Oa} + R⎠

# %%
solve(Eq(J_At.rhs,J_Oa.rhs),R)[1]
# Out:
# K_{At}⋅\mu_{Oa} - K_{Oa}⋅\mu_{At}
# ─────────────────────────────────
#        \mu_{At} - \mu_{Oa}

# %%
p1 = plot(J_Oa.rhs.subs({'\\mu_{Oa}':0.15,'K_{Oa}':0.55}),(R,0,60),show=False)
p2 = plot(J_At.rhs.subs({'\\mu_{At}':0.22,'K_{At}':15}),(R,0,60),show=False)
p1.append(p2[0])
p1.show()

# %%
plot_implicit(Eq(0.1,J_Oa_T.rhs.subs({'\\mu_{Oa}':0.43,'K_{Oa}':7,'K^T_{Oa}':7.238729356302073e-06})),(R,0,30),(T,0,2E-5*2),adaptive=False)

# %%
solve(Eq(J_At.rhs,J_Oa_T.rhs),T)
# Out:
# ⎡              K_{Oa}__T⋅\mu_{At}⋅(K_{Oa} + R)              ⎤
# ⎢───────────────────────────────────────────────────────────⎥
# ⎣K_{At}⋅\mu_{Oa} - K_{Oa}⋅\mu_{At} - R⋅\mu_{At} + R⋅\mu_{Oa}⎦
