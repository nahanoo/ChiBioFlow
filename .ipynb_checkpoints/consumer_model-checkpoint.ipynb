# %%
from monod import *

# %% [markdown]
# ## Influence of $\mu_{max}$ in batch culture

# %%
rs = np.arange(0.1,0.5,0.05)
D = 0
plot_params(rs,'r',D)
k = range(1,10)
plot_params(k,'k',D)
ys = np.arange(0.1,1.1,0.1)
plot_params(ys,'q',D)

# %%
rs = np.arange(0.1,0.5,0.05)
D = 0.1
plot_params(rs,'r',D)
k = range(1,10)
plot_params(k,'k',D)
ys = np.arange(0.1,1.1,0.1)
plot_params(ys,'q',D)
